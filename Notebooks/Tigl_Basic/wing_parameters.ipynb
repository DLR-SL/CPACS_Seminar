# %%
from tixi3 import tixi3wrapper
from tigl3 import tigl3wrapper
import tigl3.configuration

# %%
tixi_h = tixi3wrapper.Tixi3()
tigl_h = tigl3wrapper.Tigl3()

tixi_h.open("./resources/simpletest.cpacs.xml")
tigl_h.open(tixi_h, "")

# %%
# help(tigl_h)

# %% [markdown]
# 1) Initiate the aircraft configuration manager module of TiGL:

# %%
mgr = tigl3.configuration.CCPACSConfigurationManager.get_instance()
aircraft_config = mgr.get_configuration(tigl_h._handle.value)

# %% [markdown]
# 2) Get the wing you want to evaluate:

# %%
wing = aircraft_config.get_wing(1)
# help(wing)

# %% [markdown]
# 3. Do the geometric evaluations:

# %%
wing.get_surface_area()
# Out:
# 3.680788221839673

# %%
wing.get_aspect_ratio()
# Out:
# 4.571429028571439

# %%
wing.get_wingspan()
# Out:
# 4.0000002

# %%
wing.get_wing_mac()
# Out:
# [0.9047619047619049, 0.09523809523809523, 0.9047619047619048, 0.0]
